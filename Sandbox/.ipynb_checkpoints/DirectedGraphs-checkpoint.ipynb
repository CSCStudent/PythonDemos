# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ### Directed graphs
#
# - Adding and edge from A to C, creates only an edge from A to C
# - The edge from C to A has to be explicitly added, it is not implicit

# %%
G = nx.DiGraph()

G

# %%
G.add_node('A')
G.add_node('E')

G.nodes
# Out:
# NodeView(('A', 'E'))

# %%
G.add_nodes_from(['B', 'C', 'D'])

G.nodes
# Out:
# NodeView(('A', 'E', 'B', 'C', 'D'))

# %%
plt.subplots()

nx.draw(G)

# %%
def plot_graph(G, node_color, edge_color):
    
    plt.subplots(figsize=(8, 8))
    ax = plt.gca()
    ax.margins(0.20)
    plt.axis("off")

    options = {
        "font_size": 24,
        "with_labels": True,
        "node_size": 1500,
        "node_color": node_color,
        "edgecolors": edge_color,
        "linewidths": 5,
        "width": 5,
    }

    nx.draw_shell(G, **options)

# %%
plot_graph(G, "cyan", "black")

# %% [markdown]
# Note that we have an OutEdgeView rather than just a EdgeView

# %%
G.add_edge('A', 'B')

G.nodes, G.edges
# Out:
# (NodeView(('A', 'E', 'B', 'C', 'D')), OutEdgeView([('A', 'B')]))

# %%
G.add_edge('B', 'A')

G.nodes, G.edges
# Out:
# (NodeView(('A', 'E', 'B', 'C', 'D')), OutEdgeView([('A', 'B'), ('B', 'A')]))

# %%
G.add_edge('B', 'C')
G.add_edge('D', 'C')
G.add_edge('C', 'E')
G.add_edge('E', 'B')

G.nodes, G.edges
# Out:
# (NodeView(('A', 'E', 'B', 'C', 'D')),
#  OutEdgeView([('A', 'B'), ('E', 'B'), ('B', 'A'), ('B', 'C'), ('C', 'E'), ('D', 'C')]))

# %% [markdown]
# Note the edge between A and B is bi-directional, all other edges are unidirectional

# %%
plot_graph(G, "azure", "blue")

# %%
G.number_of_nodes()
# Out:
# 5

# %% [markdown]
# Note that the edge from A->B and B->A is counted twice, i.e. there are 2 edges

# %%
G.number_of_edges()
# Out:
# 6

# %% [markdown]
# Create a Graph, and convert to a DiGraph

# %%
H = nx.Graph()

H.nodes, H.edges
# Out:
# (NodeView(()), EdgeView([]))

# %%
H.add_nodes_from(['X', 'Y', 'Z'])

H.nodes, H.edges
# Out:
# (NodeView(('X', 'Y', 'Z')), EdgeView([]))

# %% [markdown]
# Cannot have multiple edges between nodes for Graph as well as DiGraph. NetworkX has a special structure called MultiGraph which supports multiple edges between nodes

# %%
H.add_edges_from([('X', 'Z'), ('X', 'Z')])

H.nodes, H.edges
# Out:
# (NodeView(('X', 'Y', 'Z')), EdgeView([('X', 'Z')]))

# %%
H.add_edges_from([('Y', 'Z'), ('X', 'Z'), ('X', 'Y')])

H.nodes, H.edges
# Out:
# (NodeView(('X', 'Y', 'Z')), EdgeView([('X', 'Z'), ('X', 'Y'), ('Y', 'Z')]))

# %%
plot_graph(H, 'magenta', 'purple')

# %% [markdown]
# Can convert undirected graphs to directed graphs, and vice-versa

# %%
H = H.to_directed()

H.nodes, H.edges
# Out:
# (NodeView(('X', 'Y', 'Z')),
#  OutEdgeView([('X', 'Z'), ('X', 'Y'), ('Y', 'Z'), ('Y', 'X'), ('Z', 'X'), ('Z', 'Y')]))

# %%
plot_graph(H, 'yellow', 'red')

# %%
G.add_nodes_from(H.nodes)

plot_graph(G, 'orange', 'brown')

# %%
G.add_edges_from(H.edges)

plot_graph(G, 'yellow', 'orange')

# %% [markdown]
# ### Degree of a node
#
# - in-degree is the number of incoming edges
# - out-degree is the number of outgoing edges
# - degree is the total of incoming and outgoing nodes
# - in an undirected graph in-degree == out-degree == degree
#
# ***In a DiGraph degree = in-degree + out-degree even though this feels inconsistent***

# %%
G.in_degree['A']
# Out:
# 1

# %%
G.in_degree['D']
# Out:
# 0

# %%
G.in_degree['B']
# Out:
# 2

# %%
G.out_degree['D']
# Out:
# 1

# %%
G.out_degree['X']
# Out:
# 2

# %%
G.out_degree['B']
# Out:
# 2

# %%
G.degree['D']
# Out:
# 1

# %%
G.degree['E']
# Out:
# 2

# %%
G.degree['Y']
# Out:
# 4

# %% [markdown]
# ### Adjacent nodes
#
# - node that are directly connected to a node
#
# ***Note here that C is adjacent to D but D is not adjacent to C***

# %%
G.adj['D']
# Out:
# AtlasView({'C': {}})

# %%
G.adj['C']
# Out:
# AtlasView({'E': {}})

# %%
G.adj['X']
# Out:
# AtlasView({'Z': {}, 'Y': {}})

# %% [markdown]
# ### Out edges and in edges
#
# Edges leading in and out of nodes

# %%
G.out_edges
# Out:
# OutEdgeView([('A', 'B'), ('E', 'B'), ('B', 'A'), ('B', 'C'), ('C', 'E'), ('D', 'C'), ('X', 'Z'), ('X', 'Y'), ('Y', 'Z'), ('Y', 'X'), ('Z', 'X'), ('Z', 'Y')])

# %%
G.in_edges
# Out:
# InEdgeView([('B', 'A'), ('C', 'E'), ('A', 'B'), ('E', 'B'), ('B', 'C'), ('D', 'C'), ('Y', 'X'), ('Z', 'X'), ('X', 'Y'), ('Z', 'Y'), ('X', 'Z'), ('Y', 'Z')])

# %%
G.has_edge('A', 'B')
# Out:
# True

# %%
G.has_edge('B', 'A')
# Out:
# True

# %%
G.has_edge('E', 'B')
# Out:
# True

# %%
G.has_edge('B', 'E')
# Out:
# False

# %% [markdown]
# ### Predecessors and successors
#
# - Predecessors: Nodes which come before a node
# - Successors: Nodes which come after a node

# %%
G.succ['Z']
# Out:
# AtlasView({'X': {}, 'Y': {}})

# %%
G.succ['B']
# Out:
# AtlasView({'A': {}, 'C': {}})

# %%
for successor in G.successors('Y'):
    print(successor)
# Out:
# Z
# X

# %%
G.pred['C']
# Out:
# AtlasView({'B': {}, 'D': {}})

# %%
G.pred['A']
# Out:
# AtlasView({'B': {}})

# %%
for predecessor in G.predecessors('B'):
    print(predecessor)
# Out:
# A
# E

# %% [markdown]
# ### Adding attributes when adding a new node
#
# Imagine that each node is associated with a city

# %%
G.add_node('Q', city='Queensland')

G.nodes
# Out:
# NodeView(('A', 'E', 'B', 'C', 'D', 'X', 'Y', 'Z', 'Q'))

# %%
G.nodes['Q']
# Out:
# {'city': 'Queensland'}

# %%
G.nodes.data()
# Out:
# NodeDataView({'A': {}, 'E': {}, 'B': {}, 'C': {}, 'D': {}, 'X': {}, 'Y': {}, 'Z': {}, 'Q': {'city': 'Queensland'}})

# %% [markdown]
# ### Adding attributes to existing nodes

# %%
G.nodes['A']['city'] = 'Armstrong'
G.nodes['B']['city'] = 'Barrie'
G.nodes['C']['city'] = 'Cabano'
G.nodes['D']['city'] = 'Devon'
G.nodes['Z']['city'] = 'Zephyr'

# %%
for data in G.nodes.data():
    print(data)
# Out:
# ('A', {'city': 'Armstrong'})
# ('E', {})
# ('B', {'city': 'Barrie'})
# ('C', {'city': 'Cabano'})
# ('D', {'city': 'Devon'})
# ('X', {})
# ('Y', {})
# ('Z', {'city': 'Zephyr'})
# ('Q', {'city': 'Queensland'})

# %%
plot_graph(G, 'pink', 'red')

# %% [markdown]
# Distance in kilometers

# %%
G.add_edge('Q', 'A', weight=245)

G.edges
# Out:
# OutEdgeView([('A', 'B'), ('E', 'B'), ('B', 'A'), ('B', 'C'), ('C', 'E'), ('D', 'C'), ('X', 'Z'), ('X', 'Y'), ('Y', 'Z'), ('Y', 'X'), ('Z', 'X'), ('Z', 'Y'), ('Q', 'A')])

# %%
for data in G.edges.data():
    print(data)
# Out:
# ('A', 'B', {'weight': 2215})
# ('E', 'B', {})
# ('B', 'A', {})
# ('B', 'C', {'weight': 1117})
# ('C', 'E', {})
# ('D', 'C', {})
# ('X', 'Z', {})
# ('X', 'Y', {})
# ('Y', 'Z', {})
# ('Y', 'X', {})
# ('Z', 'X', {})
# ('Z', 'Y', {})
# ('Q', 'A', {'distance': 245, 'weight': 245})

# %%
G.edges['A', 'B']['weight'] = 2215
G.edges['B', 'C']['weight'] = 1117

for data in G.edges.data():
    print(data)
# Out:
# ('A', 'B', {'weight': 2215})
# ('E', 'B', {})
# ('B', 'A', {})
# ('B', 'C', {'weight': 1117})
# ('C', 'E', {})
# ('D', 'C', {})
# ('X', 'Z', {})
# ('X', 'Y', {})
# ('Y', 'Z', {})
# ('Y', 'X', {})
# ('Z', 'X', {})
# ('Z', 'Y', {})
# ('Q', 'A', {'distance': 245, 'weight': 245})
